# %%
import matplotlib.pyplot as plt
import lumicks.pylake as lk
# %matplotlib notebook

# %%
directory = r'C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data\Projects\SWR1 Project\lambda nucleosome array\700-1 Condition Data Used\2021-01-25 dual color 700-1 array SWR1\h5\scans and FD curves' + '/'
file = lk.File(directory + '20210125-174026 FD Curve 1.h5')

# %%
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

# %%
force = fd.downsampled_force2.data
time = fd.downsampled_force2.timestamps
distance = fd.d.data

# %%
# %matplotlib notebook
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance, force)
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
# mask using force
mask = (force.round()==18)
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[mask], force[mask])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
# %matplotlib notebook
mask = (force.round()==15)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()

mask = (force.round()==18)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()

mask = (force.round()==20)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()

mask = (force.round()==22)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()



mask = (force.round()== 30)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()

mask = (force.round()==35)
indicies_mask = [i for i, x in enumerate(mask) if x]

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[indicies_mask[0]:indicies_mask[-1]], force[indicies_mask[0]:indicies_mask[-1]])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
# mask = (distance<15.22) & (distance>14.74)
# mask = (distance<15.485) & (distance>15.22)
mask = (distance<15.977) & (distance>15.915)

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[mask], force[mask])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
# mask = (distance<14.74) & (distance>14.55)
mask = (distance<15.257) & (distance>15.22)
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[mask], force[mask])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
# mask = (distance<15.257) & (distance>15.22)
# mask = (distance>15.445) & (distance<15.485)
# mask = (distance<15.62 & distance>15.485)

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[mask], force[mask])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
split_chrom_model = lk.inverted_odijk('DNA').subtract_independent_offset() + lk.force_offset('DNA')
split_chrom_fit = lk.FdFit(split_chrom_model)
mask = (distance<14.74) & (distance>14.55)
# mask = (distance<15.485) & (distance>15.445)
split_chrom_fit.add_data('first', force[mask], distance[mask])
mask = (distance<15.257) & (distance>15.22)
# mask = (distance<15.257) & (distance>15.22)
split_chrom_fit.add_data('second', force[mask], distance[mask],
                   params={"DNA/Lc": "DNA/Lc_2nd", "DNA/Lp": "DNA/Lp_2nd",
                           "DNA/St": "DNA/St_2nd"})
# mask = (distance<15.485) & (distance>15.445)
# split_chrom_fit.add_data('third', force[mask], distance[mask],
#                    params={"DNA/Lc": "DNA/Lc_3nd", "DNA/Lp": "DNA/Lp_3nd",
#                            "DNA/St": "DNA/St_3nd"})
# mask = (distance<15.648) & (distance>15.62)
# split_chrom_fit.add_data('fourth', force[mask], distance[mask],
#                    params={"DNA/Lc": "DNA/Lc_4nd", "DNA/Lp": "DNA/Lp_4nd",
#                            "DNA/St": "DNA/St_4nd"})
# mask = (distance<15.8) & (distance>15.67)
# split_chrom_fit.add_data('fifth', force[mask], distance[mask],
#                    params={"DNA/Lc": "DNA/Lc_5nd", "DNA/Lp": "DNA/Lp_5nd",
#                            "DNA/St": "DNA/St_5nd"})
# mask = (distance<15.977) & (distance>15.915)
# split_chrom_fit.add_data('sixth', force[mask], distance[mask],
#                    params={"DNA/Lc": "DNA/Lc_6nd", "DNA/Lp": "DNA/Lp_6nd",
#                            "DNA/St": "DNA/St_6nd"})

split_chrom_fit.fit()
# Out:
# lumicks.pylake.FdFit(models={DNA(x-d)_with_DNA}, N=9)

# %%
difference = split_chrom_fit.params['DNA/Lc_2nd'].value - split_chrom_fit.params['DNA/Lc'].value
# l6 = split_chrom_fit.params['DNA/Lc_6nd'].value
# l5 = split_chrom_fit.params['DNA/Lc_5nd'].value
# l4 = split_chrom_fit.params['DNA/Lc_4nd'].value
# l3 = split_chrom_fit.params['DNA/Lc_3nd'].value
l2 = split_chrom_fit.params['DNA/Lc_2nd'].value
l1 = split_chrom_fit.params['DNA/Lc'].value
d1 = l2 - l1
# d2 = l3 - l2
# d3 = l3 - l2
# d4 = l4 - l3
# d5 = l5 - l4
# d6 = l6 - l5


print('The difference between contour lengths is: {:.2f} nm'.format(difference*1e3))
import numpy as np
# %matplotlib inline
plt.figure(figsize=(10, 6))
split_chrom_fit.plot()
# Out:
# The difference between contour lengths is: 566.30 nm

# %%
l1,d1*1e3#, l2,d2*1e3, l3, d3*1e3, l4,d4*1e3, l5,d5*1e3, l6,d6*1e3
# d1*1e3, d2*1e3, d3*1e3, d4*1e3, d5*1e3,d6*1e3
# Out:
# (15.110679694904745, 566.2979545039573)

# %%
nn1 = d1*1e3/30
lambdaDNA = 48502
lambdaDNA/nn1, nn1
npn1 = 14050/nn1.round()


# nn2 = d2*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nn2, nn2
# npn2 = 14050/nn2.round()

# nn3 = d3*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nn3, nn3
# npn3 = 14050/nn3.round()

# nn4 = d4*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nn4, nn4
# npn4 = 14050/nn4.round()

# nn5 = d5*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nn5, nn5
# npn5 = 14050/nn5.round()

# nn6 = d6*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nn6, nn6
# npn6 = 14050/nn6.round()

# nnt = dtotal*1e3/30
# lambdaDNA = 48502
# lambdaDNA/nnt, nnt
# npnt = 14050/nnt.round()

# nn1.round(), npn1, nn2.round(), npn2, nnt.round(), npnt
nn1.round(), npn1#, nn2.round(), npn2#,nn3.round(), npn3, nn4.round(), npn4, nn5.round(), npn5,nn6.round(), npn6
# Out:
# (19.0, 739.4736842105264)

# %%
mask = (force<5.5) & (force>4.5)
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance[mask], force[mask])
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">
