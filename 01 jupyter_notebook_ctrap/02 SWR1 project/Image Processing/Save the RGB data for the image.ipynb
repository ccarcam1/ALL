# %%
## Save the RGB data for the image
import numpy as np
import matplotlib.pyplot as plt
from lumicks import pylake
import glob
import scipy.io as sio
import os

directory_h5 = r'C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5'+'/'

os.chdir(directory_h5)
# os.mkdir('kymo_mat')


files = glob.glob(directory_h5 + '*Kymograph*.h5')
print("found {} files in folder".format(len(files)))
for file_name in files:
    print(file_name)
    file = pylake.File(file_name)
    key = list(file.kymos.keys())[0]
    kymo = file.kymos[key]
#     sio.savemat(f"{directory_save}kymo_mat/kymo_{key}1125.mat",{'obj_arr':file.kymos[key].green_image})
#     sio.savemat(f"{directory_save}kymo_mat/kymoRGB_{key}20190829.mat",{f"kymoRGB_{key}20190829":file.kymos[key].rgb_image})
    kymo.save_tiff(f"{directory_h5}{key}")
#     plt.figure(figsize = [124,124])
#     kymo.plot_rgb(vmax = 2)
#     plt.savefig(key)
#     plt.close("all")
# Out:
# found 74 files in folder
# C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5\20201208-183554 Kymograph 100 DNA 6.h5
# C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5\20201208-183554 Kymograph 101 DNA 6.h5
# C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5\20201208-183554 Kymograph 109 DNA 7.h5
# C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5\20201208-183554 Kymograph 111 DNA 7.h5
# C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data_Analysis\Projects\SWR1 Project\Swc2\2020-12-08 Swc2 10nM no ATP normal salt\h5\20201208-183554 Kymograph 112 DNA 7.h5
# ...
