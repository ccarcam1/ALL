# %%
import matplotlib.pyplot as plt
import lumicks.pylake as lk
import numpy as np
import glob
# %matplotlib notebook
newlist = []
directory = r'C:\Users\carca\OneDrive - Johns Hopkins University\Ha_CCarcamo\01 Data\Projects\Roger Collaboration\RAW DATA\2021-04-09 PAM-TA preference\2021-04-09 PAM-TA preference' + '/'
which_FD_to_load = 2
lenis = len(directory)
print(lenis)

# files = glob.glob(directory +'*FD Curve*.h5')
# print("found {} files in folder".format(len(files)))
# for file_name in files:
#     print(file_name)

names = glob.glob(directory + '*FD Curve*')
[print(n[lenis:-3]) for n in names];
force = []
time = []
distance = []
# Out:
# 167
# 20210409-190231 FD Curve 1 DNA 1
# 20210409-202346 FD Curve 1 DNA 1
# 20210409-202614 FD Curve 2 DNA 2
# 20210409-203448 FD Curve 19 DNA 2 50pN then break
# 20210409-203536 FD Curve 4 DNA 3
# 20210409-203753 FD Curve 5 DNA 3 Cas9 50pN break
# 20210409-203954 FD Curve 3 DNA 4
# 20210409-204148 FD Curve 20 DNA 4 50pN break
# 20210409-204337 FD Curve 6 DNA 5
# 20210409-204601 FD Curve 21 DNA 5 Cas9 break
# 20210409-204754 FD Curve 22 DNA 6
# 20210409-205042 FD Curve 23 DNA 6 unbind
# 20210409-205220 FD Curve 7 DNA 7
# 20210409-205504 FD Curve 24 DNA 7 Cas9 cleavage 40pN
# 20210409-205555 FD Curve 8 DNA 8
# 20210409-210449 FD Curve 25 DNA 8 break
# 20210409-210733 FD Curve 9 DNA 9
# 20210409-210815 FD Curve 26 DNA 9 break
# 20210409-210927 FD Curve 11 DNA 10
# 20210409-211140 FD Curve 27 DNA 10 breaks
# 20210409-211422 FD Curve 13 DNA 11
# 20210409-211809 FD Curve 29 DNA 11 50pN break
# 20210409-211818 FD Curve 18 DNA 1 5pN
# 20210409-211821 FD Curve 17 DNA 1 50pN

# %%
file_names = ['20210409-203448 FD Curve 19 DNA 2 50pN then break', '20210409-203753 FD Curve 5 DNA 3 Cas9 50pN break','20210409-205042 FD Curve 23 DNA 6 unbind','20210409-210449 FD Curve 25 DNA 8 break','20210409-211140 FD Curve 27 DNA 10 breaks','20210409-211809 FD Curve 29 DNA 11 50pN break']

# for name in file_names:
#     file = lk.File(directory + name + '.h5')
#     newlist = []
#     for i in file.fdcurves.keys():
#         newlist.append(i)  
#     newlist
#     fd = file.fdcurves[newlist[0]]
#     force.append(fd.downsampled_force2.data)
#     t1 = fd.downsampled_force2.timestamps
#     # time = fd.downsampled_force2.timestamps
#     time.append((t1 - t1[0]) * 1e-9)
#     distance.append(fd.d.data)
    

# file_name = '20210409-211809 FD Curve 29 DNA 11 50pN break'
file_name = file_names[0]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

# %%
force0 = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time0 = (t1 - t1[0]) * 1e-9 
distance0 = fd.d.data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-fb3a39c93fe6> in <module>
# ----> 1 force0 = np.array()
#       2 time0 = np.array()
#       3 distance0 = np.array()
#       4
#       5 force0 = fd.downsampled_force2.data
#
# TypeError: array() missing required argument 'object' (pos 1)

# %%
file_name = file_names[0]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

plt.figure(figsize=(5.5, 4.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
########################################################

file_name = file_names[1]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

# plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
#################################################################
file_name = file_names[2]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

# plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
####################################################
file_name = file_names[3]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

# plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
####################################################
file_name = file_names[4]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

# plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
####################################################
file_name = file_names[5]
file = lk.File(directory + file_name + '.h5')
newlist = []
for i in file.fdcurves.keys():
    newlist.append(i)  
newlist
fd = file.fdcurves[newlist[0]]

force = []
time = []
distance = []
force = fd.downsampled_force2.data
t2 = fd.downsampled_force2.timestamps
t1 = fd.downsampled_force2.timestamps
# time = fd.downsampled_force2.timestamps
time = (t1 - t1[0]) * 1e-9 
distance = fd.d.data

# plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time-time[force>5.2][0], force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
####################################################
plt.xlim((-0.5, 65))
plt.show()
plt.savefig("time2break50pNTAPAM_4_09_2021.svg")
# Out:
# <img src="data:image/png;base64,..." width="1484.0741789128465">

# %%
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time0, force0)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
plt.plot(time1, force1)
# plt.plot(time2, force2)
# plt.plot(time3, force3)
# plt.plot(time4, force4)
# plt.plot(time5, force5)
plt.show()
# Out:
# <div id='1b806d22-a1c0-4532-a56b-ebcaffb5afb4'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-adfe1043877d> in <module>
#       2 plt.rcParams['font.size'] = 8
#       3 plt.rcParams['figure.figsize'] = (9, 6)
# ----> 4 plt.plot(time0, force0)
#       5 plt.ylabel('Force (pN)')
#       6 plt.xlabel('Time (s)')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1026,) and (870,)

# %%
# %matplotlib notebook
plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 6
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(distance, force,linewidth = 0.25)
plt.ylabel('Force (pN)')
plt.xlabel('Distance (um)')
plt.show()
plt.savefig(file_name+'force v distance'+'.svg')
# plt.savefig(file_name+' FD plot.png',bbox_inches='tight', pad_inches=0.1)

plt.figure(figsize=(2.5, 1.5))
plt.rcParams['font.size'] = 8
plt.rcParams['figure.figsize'] = (9, 6)
plt.plot(time, force)
plt.ylabel('Force (pN)')
plt.xlabel('Time (s)')
plt.show()
# plt.savefig(file_name+' FT plot.png',bbox_inches='tight', pad_inches=0.1)
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
x = 50 
mask = force.round(0)==x 
time2break = time[mask][-1] - time[mask][0]
time2break
# Out:
# 20.931993600000002

# %% [markdown]
# proximal DNA 2 time2break = 48.7 seconds
# proximal DNA 3 time2break = 62.1 seconds
# proximal DNA 6 time2break = 11.9 seconds
# proximal DNA 8 time2break = 48.9 seconds
# proximal DNA 10 time2break = 19.0 seconds
#
# distal DNA 11 time2break = 20.9 seconds`

# %%
# np.histogram([48.7, 62.1, 11.9, 48.9, 19.0, 20.9], 2)
a = [48.7, 62.1, 11.9, 48.9, 19.0, 20.9]
import matplotlib.pyplot as plt
plt.figure(figsize=(2.5, 1.5))
plt.hist(a, bins=5) 

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="674.0741216923835">

# %%
b = a.sort()
print(b)
# Out:
# None
